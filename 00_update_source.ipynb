# %% [markdown]
# # ソースデータを更新する

# %% [markdown]
# ## ブキリストを更新する
#
# - input
#   - なし
# - output
#   - メインウェポンの一覧 (`SOURCE_MAIN_PATH`)
#   - サブウェポンの一覧 (`SOURCE_SUB_PATH`)
#   - スペシャルウェポンの一覧 (`SOURCE_SPECIAL_PATH`)
#   - ブキ種の一覧 (`SOURCE_TYPE_PATH`)

# %%
import src.scraping as s

s.update_source_weapons()

# %%
import pandas as pd
import src.constants as c

pd.read_csv(c.SOURCE_MAIN_PATH)
# Out:
#                     Key            Name      Type Type Name           Sub  \
# 0                 52gal          .52ガロン   shooter     シューター  splashshield
# 1                 96gal          .96ガロン   shooter     シューター     sprinkler
# 2                  bold        ボールドマーカー   shooter     シューター   curlingbomb
# 3          bottlegeyser         ボトルガイザー   shooter     シューター  splashshield
# 4   heroshooter_replica  ヒーローシューター レプリカ   shooter     シューター    kyubanbomb
# ..                  ...             ...       ...       ...           ...
# 63       campingshelter     キャンピングシェルター    brella     シェルター    jumpbeacon
# 64          parashelter         パラシェルター    brella     シェルター     sprinkler
# 65            spygadget        スパイガジェット    brella     シェルター          trap
# 66              lact450        LACT-450  stringer    ストリンガー   curlingbomb
# 67          tristringer       トライストリンガー  stringer    ストリンガー    poisonmist
#
#       Sub Name        Special   Special Name
# ...

# %% [markdown]
# ## ステージリストを更新する
#
# - input
#   - なし
# - output
#   - ルールの一覧 (`SOURCE_STAGE_PATH`)

# %%
import src.scraping as s

s.update_source_stages()

# %%
import pandas as pd
import src.constants as c

pd.read_csv(c.SOURCE_STAGE_PATH)
# Out:
#          Key         Name
# 0   yunohana      ユノハナ大渓谷
# 1     gonzui       ゴンズイ地区
# 2   kinmedai     キンメダイ美術館
# 3    mategai      マテガイ放水路
# 4     namero       ナメロウ金属
# 5     yagara        ヤガラ市場
# 6     masaba      マサバ海峡大橋
# 7   mahimahi  マヒマヒリゾート＆スパ
# 8      zatou     ザトウマーケット
# 9    chozame      チョウザメ造船
# 10     amabi       海女美術大学
# 11   sumeshi    スメーシーワールド
# 12    hirame      ヒラメが丘団地
# 13    kusaya        クサヤ温泉

# %% [markdown]
# ## ルールリストを更新する
#
# - input
#   - なし
# - output
#   - ルールの一覧 (`SOURCE_RULE_PATH`)

# %%
import src.scraping as s

s.update_source_rules()

# %%
import pandas as pd
import src.constants as c

pd.read_csv(c.SOURCE_RULE_PATH)
# Out:
#         Key  Name
# 0  nawabari  ナワバリ
# 1      area   エリア
# 2    yagura   ヤグラ
# 3      hoko    ホコ
# 4     asari   アサリ

# %% [markdown]
# ## ロビーリストを更新する
#
# - input
#   - なし
# - output
#   - ルールの一覧 (`SOURCE_LOBBY_PATH`)

# %%
import src.scraping as s

s.update_source_lobbies()

# %%
import pandas as pd
import src.constants as c

pd.read_csv(c.SOURCE_LOBBY_PATH)
# Out:
#                    Key             Name
# 0              regular         レギュラーマッチ
# 1    bankara_challenge  バンカラマッチ (チャレンジ)
# 2         bankara_open   バンカラマッチ (オープン)
# 3               xmatch             Xマッチ
# 4  splatfest_challenge    フェスマッチ（チャレンジ）
# 5       splatfest_open     フェスマッチ（オープン）
# 6              private        プライベートマッチ
