# %% [markdown]
# # Xパワーの分布を可視化する

# %%
import datetime as dt
import src.analytics2 as a
import src.visualize2 as v

# Context
date_from = dt.date(2022, 12, 19)
date_to = date_from + dt.timedelta(days=7)

f"{str(date_from)} <= date < {str(date_to)}"
# Out:
# '2022-12-19 <= date < 2022-12-26'

# %%
details = a.read_details_from_to(date_from, date_to)
details["mode"].value_counts()
# Out:
# area      3211
# yagura    2289
# hoko      2044
# asari     1259
# Name: mode, dtype: int64

# %%
details["x-power"].describe()
# Out:
# count    8464.000000
# mean     2045.142958
# std       288.481834
# min      1190.000000
# 25%      1830.000000
# 50%      2050.000000
# 75%      2270.000000
# max      2790.000000
# Name: x-power, dtype: float64

# %%
plt, ax = v.show_xpower_dist(details)
plt.show()
